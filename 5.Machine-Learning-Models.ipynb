# %% [markdown]
# # Machine Learning Models

# %% [markdown]
# There are various Machine Learning algorithms, techniques and methods that can be used to build models for solving real-life problems by using data. In this chapter, we are going to discuss such different kinds of methods.
#
# There are four main types of machine learning methods classified based on human supervision −
#
#
# 1. Supervised Learning
#
#        1.1. Classification
#
#             1.1.1. Logistic Regression
#
#             1.1.2. Decision Trees
#
#             1.1.3. Random Forest
#
#             1.1.4. K-nearest Neighbor
#
#             1.1.5. Support Vector Machine
#
#             1.1.6. Naive Bayes
#
#             1.1.7. Linear Discriminant Analysis
#
#             1.1.8. Neural Networks
#
#        1.2. Regression
#
#             1.2.1. Linear Regression
#
#             1.2.2. Ridge regression
#
#             1.2.3. Decision Trees
#
#             1.2.4. Random Forest
#
#             1.2.5. K-nearest Neighbor
#
#             1.2.6. Neural Network Regression
#
#
#
# 2. Unsupervised Learning
#
#         2.1. Clustering
#
#             2.1.1. K-Means Clustering
#
#             2.1.2. Hierarchical Clustering
#
#             2.1.3. Mean-shift Clustering
#
#             2.1.4. DBSCAN Clustering
#
#             2.1.5. HDBSCAN Clustering
#
#             2.1.6. BIRCH Clustering
#
#             2.1.7. Affinity Propagation
#
#             2.1.8. Agglomerative Clustering
#
#         2.2. Association
#
#             2.2.1. Apriori Algorithm
#
#             2.2.2. Eclat algorithm
#
#             2.2.3. FP-growth algorithm
#
#         2.3 Dimensionality Reduction
#
#             2.3.1 Principal Component Analysis(PCA)
#
#             2.3.2. Autoencoders
#
#             2.3.3. Singular value decomposition (SVD)
#
#
# 3. Semi-supervised Learning
#
#
# 4. Reinforcement Learning
#
#     4.1. Q-learning
#
#     4.2. Markov Decision Process (MDP)
#
#     4.3. SARSA
#
#     4.4. DQN
#
#     4.5. DDPG
#     Reinforcement Learning
